# %%
# !pip install torch
# Out:
# Collecting torch
#   Downloading torch-2.9.1-cp313-cp313-win_amd64.whl.metadata (30 kB)
# Requirement already satisfied: filelock in c:\users\admin\anaconda3\lib\site-packages (from torch) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\admin\anaconda3\lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\admin\anaconda3\lib\site-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\admin\anaconda3\lib\site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\admin\anaconda3\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\admin\anaconda3\lib\site-packages (from torch) (2025.3.2)
# Requirement already satisfied: setuptools in c:\users\admin\anaconda3\lib\site-packages (from torch) (72.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\admin\anaconda3\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\admin\anaconda3\lib\site-packages (from jinja2->torch) (3.0.2)
# Downloading torch-2.9.1-cp313-cp313-win_amd64.whl (110.9 MB)
#    ---------------------------------------- 0.0/110.9 MB ? eta -:--:--
#    ---------------------------------------- 0.8/110.9 MB 8.9 MB/s eta 0:00:13
#    - -------------------------------------- 5.0/110.9 MB 16.8 MB/s eta 0:00:07
#    ---- ----------------------------------- 11.3/110.9 MB 22.7 MB/s eta 0:00:05
#    ------ --------------------------------- 17.0/110.9 MB 24.3 MB/s eta 0:00:04
#    -------- ------------------------------- 24.4/110.9 MB 26.4 MB/s eta 0:00:04
#    ----------- ---------------------------- 31.5/110.9 MB 27.8 MB/s eta 0:00:03
#    ------------- -------------------------- 37.5/110.9 MB 27.6 MB/s eta 0:00:03
#    ---------------- ----------------------- 44.6/110.9 MB 28.2 MB/s eta 0:00:03
#    ------------------ --------------------- 51.4/110.9 MB 28.7 MB/s eta 0:00:03
#    -------------------- ------------------- 57.9/110.9 MB 29.1 MB/s eta 0:00:02
#    ----------------------- ---------------- 64.7/110.9 MB 29.6 MB/s eta 0:00:02
#    ------------------------- -------------- 72.1/110.9 MB 29.9 MB/s eta 0:00:02
#    ---------------------------- ----------- 79.4/110.9 MB 30.2 MB/s eta 0:00:02
#    ------------------------------- -------- 86.5/110.9 MB 30.3 MB/s eta 0:00:01
#    --------------------------------- ------ 93.3/110.9 MB 30.5 MB/s eta 0:00:01
#    ----------------------------------- --- 100.1/110.9 MB 30.6 MB/s eta 0:00:01
#    ------------------------------------- - 107.2/110.9 MB 30.8 MB/s eta 0:00:01
#    --------------------------------------  110.9/110.9 MB 30.8 MB/s eta 0:00:01
#    --------------------------------------  110.9/110.9 MB 30.8 MB/s eta 0:00:01
#    --------------------------------------- 110.9/110.9 MB 27.0 MB/s eta 0:00:00
# Installing collected packages: torch
# Successfully installed torch-2.9.1
#
#   Downloading torch-2.9.1-cp313-cp313-win_amd64.whl.metadata (30 kB)
# Requirement already satisfied: filelock in c:\users\admin\anaconda3\lib\site-packages (from torch) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\admin\anaconda3\lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\admin\anaconda3\lib\site-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\admin\anaconda3\lib\site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\admin\anaconda3\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\admin\anaconda3\lib\site-packages (from torch) (2025.3.2)
# Requirement already satisfied: setuptools in c:\users\admin\anaconda3\lib\site-packages (from torch) (72.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\admin\anaconda3\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\admin\anaconda3\lib\site-packages (from jinja2->torch) (3.0.2)
# Downloading torch-2.9.1-cp313-cp313-win_amd64.whl (110.9 MB)
#    ---------------------------------------- 0.0/110.9 MB ? eta -:--:--
#    ---------------------------------------- 0.8/110.9 MB 8.9 MB/s eta 0:00:13
#    - -------------------------------------- 5.0/110.9 MB 16.8 MB/s eta 0:00:07
#    ---- ----------------------------------- 11.3/110.9 MB 22.7 MB/s eta 0:00:05
#    ------ --------------------------------- 17.0/110.9 MB 24.3 MB/s eta 0:00:04
#    -------- ------------------------------- 24.4/110.9 MB 26.4 MB/s eta 0:00:04
#    ----------- ---------------------------- 31.5/110.9 MB 27.8 MB/s eta 0:00:03
#    ------------- -------------------------- 37.5/110.9 MB 27.6 MB/s eta 0:00:03
#    ---------------- ----------------------- 44.6/110.9 MB 28.2 MB/s eta 0:00:03
#    ------------------ --------------------- 51.4/110.9 MB 28.7 MB/s eta 0:00:03
#    -------------------- ------------------- 57.9/110.9 MB 29.1 MB/s eta 0:00:02
#    ----------------------- ---------------- 64.7/110.9 MB 29.6 MB/s eta 0:00:02
#    ------------------------- -------------- 72.1/110.9 MB 29.9 MB/s eta 0:00:02
#    ---------------------------- ----------- 79.4/110.9 MB 30.2 MB/s eta 0:00:02
#    ------------------------------- -------- 86.5/110.9 MB 30.3 MB/s eta 0:00:01
#    --------------------------------- ------ 93.3/110.9 MB 30.5 MB/s eta 0:00:01
#    ----------------------------------- --- 100.1/110.9 MB 30.6 MB/s eta 0:00:01
#    ------------------------------------- - 107.2/110.9 MB 30.8 MB/s eta 0:00:01
#    --------------------------------------  110.9/110.9 MB 30.8 MB/s eta 0:00:01
#    --------------------------------------  110.9/110.9 MB 30.8 MB/s eta 0:00:01
#    --------------------------------------- 110.9/110.9 MB 27.0 MB/s eta 0:00:00
# Installing collected packages: torch
# Successfully installed torch-2.9.1

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tqdm import tqdm
import torch
from torch import nn, optim
from torch.utils.data import DataLoader, Dataset

# %%
import sys
from pathlib import Path

# Tự động thêm root project vào path (dù bạn ở thư mục con nào)
root_path = Path().resolve().parent  # từ training lên 1 cấp → root
if str(root_path) not in sys.path:
    sys.path.insert(0, str(root_path))

print("Đã thêm root:", root_path)



from xuLyDuLieu.fcae import extract_features, FCAE, FeaturesDataset
print("HOÀN TẤT! Bây giờ dùng được rồi!")
# Out:
# Đã thêm root: D:\nckh\SARSA_FinancialRL
# HOÀN TẤT! Bây giờ dùng được rồi!

# %% [markdown]
# # Lấy dữ liệu

# %%
# lấy từ file data\FPT_detail_2013_01_01_2024_12_31.csv
import pandas as pd
from pathlib import Path

# Xây đường dẫn tương đối so với thư mục notebook này (training/)
data_file = Path('..') / 'data' / 'FPT_detail_2013_01_01_2024_12_31.csv'

if not data_file.exists():
    raise FileNotFoundError(f"Không tìm thấy tập tin: {data_file.resolve()}")

# Đọc file CSV vào biến price_history (phân tích cột 'Date' nếu có)
try:
    price_history = pd.read_csv(data_file, parse_dates=['Date'], dayfirst=False)
except ValueError:
    # Nếu không có cột 'Date', đọc bình thường và giữ nguyên dữ liệu
    price_history = pd.read_csv(data_file)

# Sắp theo cột 'Date' nếu có và đặt lại index để DataFrame gọn gàng
if 'Date' in price_history.columns:
    price_history = price_history.sort_values('Date').reset_index(drop=True)

# Xem nhanh (bỏ hoặc comment dòng này khi không cần)
price_history.head()
# Out:
#          time  open  high   low  close  volume
# 0  20-06-2012  5.31  5.31  5.27   5.29   89720
# 1  21-06-2012  5.28  5.29  5.26   5.28   50360
# 2  22-06-2012  5.27  5.28  5.26   5.26   67350
# 3  25-06-2012  5.25  5.29  5.25   5.26   42840
# 4  26-06-2012  5.22  5.24  5.22   5.22   31110

# %% [markdown]
# # Huấn luyện FCAE

# %%
encoded_features, trained_model, loss_history = extract_features(
    price_history=price_history,   # DataFrame của bạn
    past_days=32,
    epochs=100
)

# Dùng encoded_features để train mô hình chính (LSTM, Transformer, v.v.)
print("Features shape:", encoded_features.shape)  # ví dụ: (2500, 8)
# Out:
# Training FCAE: 100%|██████████| 100/100 [00:09<00:00, 10.71it/s]
# Extract features hoàn tất! Shape: (3102, 8)
# Features shape: (3102, 8)
