# %% [markdown]
# # Test Pipeline với Vnstock
# Notebook này kiểm tra việc lấy dữ liệu từ Vnstock, tiền xử lý và chuẩn bị cho mô hình.

# %%
import sys
sys.path.append('d:/NCKH/SARSA_FinancialRL')  # chỉnh path tới project

from meta.data_processor import DataProcessor
from meta.preprocessor.preprocessors import FeatureEngineer, data_split
import pandas as pd

# %%
# Khởi tạo DataProcessor với nguồn vnstock
dp = DataProcessor(data_source='vnstock')

# Lấy dữ liệu ví dụ cho mã VNM
data = dp.download_data(ticker_list=['VNM'], start_date='2024-01-01', end_date='2024-06-30')
data.head()
# Out:
#    timestamp   open   high    low  close   volume  tic
# 0 2024-01-02  62.35  62.62  62.08  62.44  2144983  VNM
# 1 2024-01-03  62.53  63.08  62.17  63.08  1891530  VNM
# 2 2024-01-04  63.17  63.54  63.08  63.08  3403997  VNM
# 3 2024-01-05  63.36  63.36  62.62  62.90  1477880  VNM
# 4 2024-01-08  63.08  63.17  62.35  62.35  2399171  VNM

# %%
print(data.columns)
# Out:
# Index(['timestamp', 'open', 'high', 'low', 'close', 'volume', 'tic'], dtype='object')

# %%
# Kiểm tra shape và thông tin
print('Original shape:', data.shape)
print('Processed shape:', scaled_data.shape)
# Out:
# Original shape: (120, 7)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 3
#       1 # Kiểm tra shape và thông tin
#       2 print('Original shape:', data.shape)
# ----> 3 print('Processed shape:', scaled_data.shape)
#
# NameError: name 'scaled_data' is not defined
