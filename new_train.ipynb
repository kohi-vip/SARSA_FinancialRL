# %%
## install required packages
# !pip install swig
# !pip install wrds
# !pip install pyportfolioopt
## install finrl library
# !pip install git+https://github.com/AI4Finance-Foundation/FinRL.git
# Out:
# Requirement already satisfied: swig in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (4.3.1.post0)
# Requirement already satisfied: wrds in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (3.4.0)
# Requirement already satisfied: packaging<=24.2 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from wrds) (24.2)
# Requirement already satisfied: pandas<2.3,>=2.2 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from wrds) (2.2.3)
# Requirement already satisfied: psycopg2-binary<2.10,>=2.9 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from wrds) (2.9.10)
# Requirement already satisfied: sqlalchemy<2.1,>=2 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from wrds) (2.0.43)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from pandas<2.3,>=2.2->wrds) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from pandas<2.3,>=2.2->wrds) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from pandas<2.3,>=2.2->wrds) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from pandas<2.3,>=2.2->wrds) (2023.3)
# Requirement already satisfied: greenlet>=1 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from sqlalchemy<2.1,>=2->wrds) (3.2.4)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from sqlalchemy<2.1,>=2->wrds) (4.12.2)
# Requirement already satisfied: six>=1.5 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from python-dateutil>=2.8.2->pandas<2.3,>=2.2->wrds) (1.16.0)
# Requirement already satisfied: wrds in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (3.4.0)
# Requirement already satisfied: packaging<=24.2 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from wrds) (24.2)
# Requirement already satisfied: pandas<2.3,>=2.2 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from wrds) (2.2.3)
# Requirement already satisfied: psycopg2-binary<2.10,>=2.9 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from wrds) (2.9.10)
# Requirement already satisfied: sqlalchemy<2.1,>=2 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from wrds) (2.0.43)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from pandas<2.3,>=2.2->wrds) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from pandas<2.3,>=2.2->wrds) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from pandas<2.3,>=2.2->wrds) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from pandas<2.3,>=2.2->wrds) (2023.3)
# Requirement already satisfied: greenlet>=1 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from sqlalchemy<2.1,>=2->wrds) (3.2.4)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from sqlalchemy<2.1,>=2->wrds) (4.12.2)
# Requirement already satisfied: six>=1.5 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from python-dateutil>=2.8.2->pandas<2.3,>=2.2->wrds) (1.16.0)
# Requirement already satisfied: pyportfolioopt in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (1.5.6)
# Requirement already satisfied: cvxpy>=1.1.19 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from pyportfolioopt) (1.7.2)
# Requirement already satisfied: ecos<3.0.0,>=2.0.14 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from pyportfolioopt) (2.0.14)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from pyportfolioopt) (2.2.6)
# Requirement already satisfied: pandas>=0.19 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from pyportfolioopt) (2.2.3)
# Requirement already satisfied: plotly<6.0.0,>=5.0.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from pyportfolioopt) (5.24.1)
# Requirement already satisfied: scipy>=1.3 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from pyportfolioopt) (1.15.3)
# Requirement already satisfied: osqp>=0.6.2 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from cvxpy>=1.1.19->pyportfolioopt) (1.0.4)
# Requirement already satisfied: clarabel>=0.5.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from cvxpy>=1.1.19->pyportfolioopt) (0.11.1)
# Requirement already satisfied: scs>=3.2.4.post1 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from cvxpy>=1.1.19->pyportfolioopt) (3.2.8)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from pandas>=0.19->pyportfolioopt) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from pandas>=0.19->pyportfolioopt) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from pandas>=0.19->pyportfolioopt) (2023.3)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from plotly<6.0.0,>=5.0.0->pyportfolioopt) (9.1.2)
# Requirement already satisfied: packaging in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from plotly<6.0.0,>=5.0.0->pyportfolioopt) (24.2)
# Requirement already satisfied: cffi in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from clarabel>=0.5.0->cvxpy>=1.1.19->pyportfolioopt) (1.17.1)
# Requirement already satisfied: jinja2 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from osqp>=0.6.2->cvxpy>=1.1.19->pyportfolioopt) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from osqp>=0.6.2->cvxpy>=1.1.19->pyportfolioopt) (75.8.0)
# Requirement already satisfied: joblib in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from osqp>=0.6.2->cvxpy>=1.1.19->pyportfolioopt) (1.5.2)
# Requirement already satisfied: six>=1.5 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.19->pyportfolioopt) (1.16.0)
# Requirement already satisfied: pycparser in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from cffi->clarabel>=0.5.0->cvxpy>=1.1.19->pyportfolioopt) (2.22)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from jinja2->osqp>=0.6.2->cvxpy>=1.1.19->pyportfolioopt) (3.0.2)
# Requirement already satisfied: pyportfolioopt in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (1.5.6)
# Requirement already satisfied: cvxpy>=1.1.19 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from pyportfolioopt) (1.7.2)
# Requirement already satisfied: ecos<3.0.0,>=2.0.14 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from pyportfolioopt) (2.0.14)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from pyportfolioopt) (2.2.6)
# Requirement already satisfied: pandas>=0.19 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from pyportfolioopt) (2.2.3)
# Requirement already satisfied: plotly<6.0.0,>=5.0.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from pyportfolioopt) (5.24.1)
# Requirement already satisfied: scipy>=1.3 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from pyportfolioopt) (1.15.3)
# Requirement already satisfied: osqp>=0.6.2 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from cvxpy>=1.1.19->pyportfolioopt) (1.0.4)
# Requirement already satisfied: clarabel>=0.5.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from cvxpy>=1.1.19->pyportfolioopt) (0.11.1)
# Requirement already satisfied: scs>=3.2.4.post1 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from cvxpy>=1.1.19->pyportfolioopt) (3.2.8)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from pandas>=0.19->pyportfolioopt) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from pandas>=0.19->pyportfolioopt) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from pandas>=0.19->pyportfolioopt) (2023.3)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from plotly<6.0.0,>=5.0.0->pyportfolioopt) (9.1.2)
# Requirement already satisfied: packaging in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from plotly<6.0.0,>=5.0.0->pyportfolioopt) (24.2)
# Requirement already satisfied: cffi in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from clarabel>=0.5.0->cvxpy>=1.1.19->pyportfolioopt) (1.17.1)
# Requirement already satisfied: jinja2 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from osqp>=0.6.2->cvxpy>=1.1.19->pyportfolioopt) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from osqp>=0.6.2->cvxpy>=1.1.19->pyportfolioopt) (75.8.0)
# Requirement already satisfied: joblib in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from osqp>=0.6.2->cvxpy>=1.1.19->pyportfolioopt) (1.5.2)
# Requirement already satisfied: six>=1.5 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.19->pyportfolioopt) (1.16.0)
# Requirement already satisfied: pycparser in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from cffi->clarabel>=0.5.0->cvxpy>=1.1.19->pyportfolioopt) (2.22)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from jinja2->osqp>=0.6.2->cvxpy>=1.1.19->pyportfolioopt) (3.0.2)
# Collecting git+https://github.com/AI4Finance-Foundation/FinRL.git
#   Cloning https://github.com/AI4Finance-Foundation/FinRL.git to c:\users\admin\appdata\local\temp\pip-req-build-_ow2_5vt
#   Resolved https://github.com/AI4Finance-Foundation/FinRL.git to commit dcf6bde8d64e1a747673d24dde30dce195bc3cf1
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git (from finrl==0.3.8)
#   Cloning https://github.com/AI4Finance-Foundation/ElegantRL.git to c:\users\admin\appdata\local\temp\pip-install-9z1w5efd\elegantrl_3ad6fb0bfbb94d7a81291d32c54c57a9
#   Resolved https://github.com/AI4Finance-Foundation/ElegantRL.git to commit 37aac1f592e1add9f9fd37ae8db1094656009b76
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: alpaca-py<0.38,>=0.37 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from finrl==0.3.8) (0.37.0)
# Requirement already satisfied: alpaca-trade-api<4,>=3 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from finrl==0.3.8) (3.2.0)
# Requirement already satisfied: ccxt<4,>=3 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from finrl==0.3.8) (3.1.60)
# Requirement already satisfied: jqdatasdk<2,>=1 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from finrl==0.3.8) (1.9.7)
# Requirement already satisfied: pandas-market-calendars<6,>=5 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from finrl==0.3.8) (5.1.1)
# Requirement already satisfied: pyfolio-reloaded<0.10,>=0.9 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from finrl==0.3.8) (0.9.9)
# Requirement already satisfied: pyportfolioopt<2,>=1 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from finrl==0.3.8) (1.5.6)
# Requirement already satisfied: ray<3,>=2 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (2.49.0)
# Requirement already satisfied: scikit-learn<2,>=1 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from finrl==0.3.8) (1.7.1)
# Requirement already satisfied: selenium<5,>=4 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from finrl==0.3.8) (4.32.0)
# Requirement already satisfied: stable-baselines3>=2.0.0a5 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (2.7.0)
# Requirement already satisfied: stockstats<0.6,>=0.5 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from finrl==0.3.8) (0.5.4)
# Requirement already satisfied: webdriver-manager<5,>=4 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from finrl==0.3.8) (4.0.2)
# Requirement already satisfied: wrds<4,>=3 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from finrl==0.3.8) (3.4.0)
# Requirement already satisfied: yfinance<0.3,>=0.2 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from finrl==0.3.8) (0.2.58)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.3 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from alpaca-py<0.38,>=0.37->finrl==0.3.8) (1.0.3)
# Requirement already satisfied: pandas>=1.5.3 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from alpaca-py<0.38,>=0.37->finrl==0.3.8) (2.2.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.3 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from alpaca-py<0.38,>=0.37->finrl==0.3.8) (2.11.7)
# Requirement already satisfied: requests<3.0.0,>=2.30.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from alpaca-py<0.38,>=0.37->finrl==0.3.8) (2.32.3)
# Requirement already satisfied: sseclient-py<2.0.0,>=1.7.2 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from alpaca-py<0.38,>=0.37->finrl==0.3.8) (1.8.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from alpaca-py<0.38,>=0.37->finrl==0.3.8) (10.4)
# Requirement already satisfied: numpy>=1.11.1 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.8) (2.2.6)
# Requirement already satisfied: urllib3<2,>1.24 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.8) (1.26.20)
# Requirement already satisfied: websocket-client<2,>=0.56.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.8) (1.8.0)
# Requirement already satisfied: aiohttp<4,>=3.8.3 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.8) (3.12.15)
# Requirement already satisfied: PyYAML==6.0.1 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.8) (6.0.1)
# Requirement already satisfied: deprecation==2.1.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.8) (2.1.0)
# Requirement already satisfied: packaging in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from deprecation==2.1.0->alpaca-trade-api<4,>=3->finrl==0.3.8) (24.2)
# Requirement already satisfied: setuptools>=60.9.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from ccxt<4,>=3->finrl==0.3.8) (75.8.0)
# Requirement already satisfied: certifi>=2018.1.18 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from ccxt<4,>=3->finrl==0.3.8) (2025.1.31)
# Requirement already satisfied: cryptography>=2.6.1 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from ccxt<4,>=3->finrl==0.3.8) (45.0.6)
# Requirement already satisfied: aiodns>=1.1.1 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from ccxt<4,>=3->finrl==0.3.8) (3.5.0)
# Requirement already satisfied: yarl>=1.7.2 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from ccxt<4,>=3->finrl==0.3.8) (1.20.1)
# Requirement already satisfied: six in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from jqdatasdk<2,>=1->finrl==0.3.8) (1.16.0)
# Requirement already satisfied: SQLAlchemy>=1.2.8 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from jqdatasdk<2,>=1->finrl==0.3.8) (2.0.43)
# Requirement already satisfied: pymysql>=0.7.6 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from jqdatasdk<2,>=1->finrl==0.3.8) (1.1.2)
# Requirement already satisfied: thriftpy2<=0.4.20,>=0.3.9 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from jqdatasdk<2,>=1->finrl==0.3.8) (0.4.20)
# Requirement already satisfied: tzdata in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from pandas-market-calendars<6,>=5->finrl==0.3.8) (2023.3)
# Requirement already satisfied: python-dateutil in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from pandas-market-calendars<6,>=5->finrl==0.3.8) (2.9.0.post0)
# Requirement already satisfied: exchange-calendars>=3.3 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from pandas-market-calendars<6,>=5->finrl==0.3.8) (4.11.1)
# Requirement already satisfied: ipython>=3.2.3 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (9.0.2)
# Requirement already satisfied: matplotlib>=1.4.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (3.10.3)
# Requirement already satisfied: pytz>=2014.10 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (2024.1)
# Requirement already satisfied: scipy>=0.14.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (1.15.3)
# Requirement already satisfied: seaborn>=0.7.1 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.13.2)
# Requirement already satisfied: empyrical-reloaded>=0.5.9 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.5.12)
# Requirement already satisfied: cvxpy>=1.1.19 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from pyportfolioopt<2,>=1->finrl==0.3.8) (1.7.2)
# Requirement already satisfied: ecos<3.0.0,>=2.0.14 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from pyportfolioopt<2,>=1->finrl==0.3.8) (2.0.14)
# Requirement already satisfied: plotly<6.0.0,>=5.0.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from pyportfolioopt<2,>=1->finrl==0.3.8) (5.24.1)
# Requirement already satisfied: click>=7.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (8.2.1)
# Requirement already satisfied: filelock in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (3.19.1)
# Requirement already satisfied: jsonschema in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (4.23.0)
# Requirement already satisfied: protobuf>=3.20.3 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (6.31.0)
# Requirement already satisfied: aiohttp_cors in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (0.8.1)
# Requirement already satisfied: colorful in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (0.5.7)
# Requirement already satisfied: py-spy>=0.4.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (0.4.1)
# Requirement already satisfied: grpcio>=1.42.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (1.74.0)
# Requirement already satisfied: opencensus in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (0.11.4)
# Requirement already satisfied: opentelemetry-sdk>=1.30.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (1.36.0)
# Requirement already satisfied: opentelemetry-exporter-prometheus in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (0.57b0)
# Requirement already satisfied: opentelemetry-proto in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (1.36.0)
# Requirement already satisfied: prometheus_client>=0.7.1 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (0.21.1)
# Requirement already satisfied: smart_open in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (7.3.0.post1)
# Requirement already satisfied: virtualenv!=20.21.1,>=20.0.24 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (20.34.0)
# Requirement already satisfied: tensorboardX>=1.9 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (2.6.4)
# Requirement already satisfied: pyarrow>=9.0.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (19.0.0)
# Requirement already satisfied: fsspec in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (2025.7.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from scikit-learn<2,>=1->finrl==0.3.8) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from scikit-learn<2,>=1->finrl==0.3.8) (3.6.0)
# Requirement already satisfied: trio~=0.17 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from selenium<5,>=4->finrl==0.3.8) (0.30.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from selenium<5,>=4->finrl==0.3.8) (0.12.2)
# Requirement already satisfied: typing_extensions~=4.9 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from selenium<5,>=4->finrl==0.3.8) (4.12.2)
# Requirement already satisfied: gymnasium<1.3.0,>=0.29.1 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (1.2.0)
# Requirement already satisfied: torch<3.0,>=2.3 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (2.8.0)
# Requirement already satisfied: cloudpickle in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (3.1.1)
# Requirement already satisfied: opencv-python in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (4.12.0.88)
# Requirement already satisfied: pygame in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (2.6.1)
# Requirement already satisfied: tensorboard>=2.9.1 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (2.20.0)
# Requirement already satisfied: psutil in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (5.9.0)
# Requirement already satisfied: tqdm in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (4.67.1)
# Requirement already satisfied: rich in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (14.1.0)
# Requirement already satisfied: ale-py>=0.9.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (0.11.2)
# Requirement already satisfied: pillow in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (11.2.1)
# Requirement already satisfied: python-dotenv in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from webdriver-manager<5,>=4->finrl==0.3.8) (1.1.1)
# Requirement already satisfied: psycopg2-binary<2.10,>=2.9 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from wrds<4,>=3->finrl==0.3.8) (2.9.10)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from yfinance<0.3,>=0.2->finrl==0.3.8) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from yfinance<0.3,>=0.2->finrl==0.3.8) (4.3.6)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from yfinance<0.3,>=0.2->finrl==0.3.8) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from yfinance<0.3,>=0.2->finrl==0.3.8) (3.17.3)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from yfinance<0.3,>=0.2->finrl==0.3.8) (4.13.3)
# Requirement already satisfied: curl_cffi>=0.7 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from yfinance<0.3,>=0.2->finrl==0.3.8) (0.13.0)
# Requirement already satisfied: th in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git->finrl==0.3.8) (0.4.1)
# Requirement already satisfied: pycares>=4.9.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from aiodns>=1.1.1->ccxt<4,>=3->finrl==0.3.8) (4.10.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.8) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.8) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.8) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.8) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.8) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.8) (0.3.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance<0.3,>=0.2->finrl==0.3.8) (2.5)
# Requirement already satisfied: colorama in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from click>=7.0->ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (0.4.6)
# Requirement already satisfied: cffi>=1.14 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from cryptography>=2.6.1->ccxt<4,>=3->finrl==0.3.8) (1.17.1)
# Requirement already satisfied: osqp>=0.6.2 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from cvxpy>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.8) (1.0.4)
# Requirement already satisfied: clarabel>=0.5.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from cvxpy>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.8) (0.11.1)
# Requirement already satisfied: scs>=3.2.4.post1 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from cvxpy>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.8) (3.2.8)
# Requirement already satisfied: bottleneck>=1.3.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from empyrical-reloaded>=0.5.9->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (1.4.2)
# Requirement already satisfied: pyluach in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from exchange-calendars>=3.3->pandas-market-calendars<6,>=5->finrl==0.3.8) (2.2.0)
# Requirement already satisfied: toolz in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from exchange-calendars>=3.3->pandas-market-calendars<6,>=5->finrl==0.3.8) (1.0.0)
# Requirement already satisfied: korean_lunar_calendar in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from exchange-calendars>=3.3->pandas-market-calendars<6,>=5->finrl==0.3.8) (0.3.1)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from gymnasium<1.3.0,>=0.29.1->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (0.0.4)
# Requirement already satisfied: decorator in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (2.19.1)
# Requirement already satisfied: stack_data in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (5.14.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from matplotlib>=1.4.0->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from matplotlib>=1.4.0->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from matplotlib>=1.4.0->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from matplotlib>=1.4.0->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from matplotlib>=1.4.0->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (3.2.3)
# Requirement already satisfied: opentelemetry-api==1.36.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from opentelemetry-sdk>=1.30.0->ray[default,tune]<3,>=2->finrl==0.3.8) (1.36.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.57b0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from opentelemetry-sdk>=1.30.0->ray[default,tune]<3,>=2->finrl==0.3.8) (0.57b0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from opentelemetry-api==1.36.0->opentelemetry-sdk>=1.30.0->ray[default,tune]<3,>=2->finrl==0.3.8) (8.6.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from plotly<6.0.0,>=5.0.0->pyportfolioopt<2,>=1->finrl==0.3.8) (9.1.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from pydantic<3.0.0,>=2.0.3->alpaca-py<0.38,>=0.37->finrl==0.3.8) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from pydantic<3.0.0,>=2.0.3->alpaca-py<0.38,>=0.37->finrl==0.3.8) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from pydantic<3.0.0,>=2.0.3->alpaca-py<0.38,>=0.37->finrl==0.3.8) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from requests<3.0.0,>=2.30.0->alpaca-py<0.38,>=0.37->finrl==0.3.8) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from requests<3.0.0,>=2.30.0->alpaca-py<0.38,>=0.37->finrl==0.3.8) (3.10)
# Requirement already satisfied: greenlet>=1 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from SQLAlchemy>=1.2.8->jqdatasdk<2,>=1->finrl==0.3.8) (3.2.4)
# Requirement already satisfied: absl-py>=0.4 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (2.3.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (3.8.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (3.1.3)
# Requirement already satisfied: ply<4.0,>=3.4 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from thriftpy2<=0.4.20,>=0.3.9->jqdatasdk<2,>=1->finrl==0.3.8) (3.11)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (1.14.0)
# Requirement already satisfied: networkx in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (3.5)
# Requirement already satisfied: jinja2 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (3.1.6)
# Requirement already satisfied: sortedcontainers in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from trio~=0.17->selenium<5,>=4->finrl==0.3.8) (2.4.0)
# Requirement already satisfied: outcome in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from trio~=0.17->selenium<5,>=4->finrl==0.3.8) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from trio~=0.17->selenium<5,>=4->finrl==0.3.8) (1.3.1)
# Requirement already satisfied: wsproto>=0.14 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from trio-websocket~=0.9->selenium<5,>=4->finrl==0.3.8) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium<5,>=4->finrl==0.3.8) (1.7.1)
# Requirement already satisfied: distlib<1,>=0.3.7 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from virtualenv!=20.21.1,>=20.0.24->ray[default,tune]<3,>=2->finrl==0.3.8) (0.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from jsonschema->ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from jsonschema->ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from jsonschema->ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (0.22.3)
# Requirement already satisfied: opencensus-context>=0.1.3 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (0.1.3)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (2.25.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from rich->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (4.0.0)
# Requirement already satisfied: wrapt in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from smart_open->ray[default,tune]<3,>=2->finrl==0.3.8) (1.17.3)
# Requirement already satisfied: niltype<2.0,>=0.3 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from th->elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git->finrl==0.3.8) (1.0.2)
# Requirement already satisfied: pycparser in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from cffi>=1.14->cryptography>=2.6.1->ccxt<4,>=3->finrl==0.3.8) (2.22)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (1.70.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (1.26.1)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (2.40.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from jedi>=0.16->ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.8.4)
# Requirement already satisfied: mdurl~=0.1 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (0.1.2)
# Requirement already satisfied: wcwidth in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.2.13)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from sympy>=1.13.3->torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (3.0.2)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium<5,>=4->finrl==0.3.8) (0.14.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from stack_data->ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from stack_data->ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (3.0.0)
# Requirement already satisfied: pure_eval in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from stack_data->ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.2.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (4.9.1)
# Requirement already satisfied: zipp>=3.20 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api==1.36.0->opentelemetry-sdk>=1.30.0->ray[default,tune]<3,>=2->finrl==0.3.8) (3.21.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (0.6.1)
# Collecting git+https://github.com/AI4Finance-Foundation/FinRL.git
#   Cloning https://github.com/AI4Finance-Foundation/FinRL.git to c:\users\admin\appdata\local\temp\pip-req-build-_ow2_5vt
#   Resolved https://github.com/AI4Finance-Foundation/FinRL.git to commit dcf6bde8d64e1a747673d24dde30dce195bc3cf1
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git (from finrl==0.3.8)
#   Cloning https://github.com/AI4Finance-Foundation/ElegantRL.git to c:\users\admin\appdata\local\temp\pip-install-9z1w5efd\elegantrl_3ad6fb0bfbb94d7a81291d32c54c57a9
#   Resolved https://github.com/AI4Finance-Foundation/ElegantRL.git to commit 37aac1f592e1add9f9fd37ae8db1094656009b76
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: alpaca-py<0.38,>=0.37 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from finrl==0.3.8) (0.37.0)
# Requirement already satisfied: alpaca-trade-api<4,>=3 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from finrl==0.3.8) (3.2.0)
# Requirement already satisfied: ccxt<4,>=3 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from finrl==0.3.8) (3.1.60)
# Requirement already satisfied: jqdatasdk<2,>=1 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from finrl==0.3.8) (1.9.7)
# Requirement already satisfied: pandas-market-calendars<6,>=5 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from finrl==0.3.8) (5.1.1)
# Requirement already satisfied: pyfolio-reloaded<0.10,>=0.9 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from finrl==0.3.8) (0.9.9)
# Requirement already satisfied: pyportfolioopt<2,>=1 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from finrl==0.3.8) (1.5.6)
# Requirement already satisfied: ray<3,>=2 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (2.49.0)
# Requirement already satisfied: scikit-learn<2,>=1 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from finrl==0.3.8) (1.7.1)
# Requirement already satisfied: selenium<5,>=4 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from finrl==0.3.8) (4.32.0)
# Requirement already satisfied: stable-baselines3>=2.0.0a5 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (2.7.0)
# Requirement already satisfied: stockstats<0.6,>=0.5 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from finrl==0.3.8) (0.5.4)
# Requirement already satisfied: webdriver-manager<5,>=4 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from finrl==0.3.8) (4.0.2)
# Requirement already satisfied: wrds<4,>=3 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from finrl==0.3.8) (3.4.0)
# Requirement already satisfied: yfinance<0.3,>=0.2 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from finrl==0.3.8) (0.2.58)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.3 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from alpaca-py<0.38,>=0.37->finrl==0.3.8) (1.0.3)
# Requirement already satisfied: pandas>=1.5.3 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from alpaca-py<0.38,>=0.37->finrl==0.3.8) (2.2.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.3 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from alpaca-py<0.38,>=0.37->finrl==0.3.8) (2.11.7)
# Requirement already satisfied: requests<3.0.0,>=2.30.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from alpaca-py<0.38,>=0.37->finrl==0.3.8) (2.32.3)
# Requirement already satisfied: sseclient-py<2.0.0,>=1.7.2 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from alpaca-py<0.38,>=0.37->finrl==0.3.8) (1.8.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from alpaca-py<0.38,>=0.37->finrl==0.3.8) (10.4)
# Requirement already satisfied: numpy>=1.11.1 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.8) (2.2.6)
# Requirement already satisfied: urllib3<2,>1.24 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.8) (1.26.20)
# Requirement already satisfied: websocket-client<2,>=0.56.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.8) (1.8.0)
# Requirement already satisfied: aiohttp<4,>=3.8.3 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.8) (3.12.15)
# Requirement already satisfied: PyYAML==6.0.1 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.8) (6.0.1)
# Requirement already satisfied: deprecation==2.1.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.8) (2.1.0)
# Requirement already satisfied: packaging in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from deprecation==2.1.0->alpaca-trade-api<4,>=3->finrl==0.3.8) (24.2)
# Requirement already satisfied: setuptools>=60.9.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from ccxt<4,>=3->finrl==0.3.8) (75.8.0)
# Requirement already satisfied: certifi>=2018.1.18 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from ccxt<4,>=3->finrl==0.3.8) (2025.1.31)
# ...
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.8) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.8) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.8) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.8) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.8) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.8) (0.3.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance<0.3,>=0.2->finrl==0.3.8) (2.5)
# Requirement already satisfied: colorama in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from click>=7.0->ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (0.4.6)
# Requirement already satisfied: cffi>=1.14 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from cryptography>=2.6.1->ccxt<4,>=3->finrl==0.3.8) (1.17.1)
# Requirement already satisfied: osqp>=0.6.2 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from cvxpy>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.8) (1.0.4)
# Requirement already satisfied: clarabel>=0.5.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from cvxpy>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.8) (0.11.1)
# Requirement already satisfied: scs>=3.2.4.post1 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from cvxpy>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.8) (3.2.8)
# Requirement already satisfied: bottleneck>=1.3.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from empyrical-reloaded>=0.5.9->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (1.4.2)
# Requirement already satisfied: pyluach in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from exchange-calendars>=3.3->pandas-market-calendars<6,>=5->finrl==0.3.8) (2.2.0)
# Requirement already satisfied: toolz in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from exchange-calendars>=3.3->pandas-market-calendars<6,>=5->finrl==0.3.8) (1.0.0)
# Requirement already satisfied: korean_lunar_calendar in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from exchange-calendars>=3.3->pandas-market-calendars<6,>=5->finrl==0.3.8) (0.3.1)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from gymnasium<1.3.0,>=0.29.1->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (0.0.4)
# Requirement already satisfied: decorator in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (2.19.1)
# Requirement already satisfied: stack_data in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (5.14.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from matplotlib>=1.4.0->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from matplotlib>=1.4.0->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from matplotlib>=1.4.0->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from matplotlib>=1.4.0->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from matplotlib>=1.4.0->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (3.2.3)
# Requirement already satisfied: opentelemetry-api==1.36.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from opentelemetry-sdk>=1.30.0->ray[default,tune]<3,>=2->finrl==0.3.8) (1.36.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.57b0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from opentelemetry-sdk>=1.30.0->ray[default,tune]<3,>=2->finrl==0.3.8) (0.57b0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from opentelemetry-api==1.36.0->opentelemetry-sdk>=1.30.0->ray[default,tune]<3,>=2->finrl==0.3.8) (8.6.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from plotly<6.0.0,>=5.0.0->pyportfolioopt<2,>=1->finrl==0.3.8) (9.1.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from pydantic<3.0.0,>=2.0.3->alpaca-py<0.38,>=0.37->finrl==0.3.8) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from pydantic<3.0.0,>=2.0.3->alpaca-py<0.38,>=0.37->finrl==0.3.8) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from pydantic<3.0.0,>=2.0.3->alpaca-py<0.38,>=0.37->finrl==0.3.8) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from requests<3.0.0,>=2.30.0->alpaca-py<0.38,>=0.37->finrl==0.3.8) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from requests<3.0.0,>=2.30.0->alpaca-py<0.38,>=0.37->finrl==0.3.8) (3.10)
# Requirement already satisfied: greenlet>=1 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from SQLAlchemy>=1.2.8->jqdatasdk<2,>=1->finrl==0.3.8) (3.2.4)
# Requirement already satisfied: absl-py>=0.4 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (2.3.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (3.8.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (3.1.3)
# Requirement already satisfied: ply<4.0,>=3.4 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from thriftpy2<=0.4.20,>=0.3.9->jqdatasdk<2,>=1->finrl==0.3.8) (3.11)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (1.14.0)
# Requirement already satisfied: networkx in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (3.5)
# Requirement already satisfied: jinja2 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (3.1.6)
# Requirement already satisfied: sortedcontainers in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from trio~=0.17->selenium<5,>=4->finrl==0.3.8) (2.4.0)
# Requirement already satisfied: outcome in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from trio~=0.17->selenium<5,>=4->finrl==0.3.8) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from trio~=0.17->selenium<5,>=4->finrl==0.3.8) (1.3.1)
# Requirement already satisfied: wsproto>=0.14 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from trio-websocket~=0.9->selenium<5,>=4->finrl==0.3.8) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium<5,>=4->finrl==0.3.8) (1.7.1)
# Requirement already satisfied: distlib<1,>=0.3.7 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from virtualenv!=20.21.1,>=20.0.24->ray[default,tune]<3,>=2->finrl==0.3.8) (0.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from jsonschema->ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from jsonschema->ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from jsonschema->ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (0.22.3)
# Requirement already satisfied: opencensus-context>=0.1.3 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (0.1.3)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (2.25.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from rich->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (4.0.0)
# Requirement already satisfied: wrapt in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from smart_open->ray[default,tune]<3,>=2->finrl==0.3.8) (1.17.3)
# Requirement already satisfied: niltype<2.0,>=0.3 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from th->elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git->finrl==0.3.8) (1.0.2)
# Requirement already satisfied: pycparser in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from cffi>=1.14->cryptography>=2.6.1->ccxt<4,>=3->finrl==0.3.8) (2.22)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (1.70.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (1.26.1)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (2.40.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from jedi>=0.16->ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.8.4)
# Requirement already satisfied: mdurl~=0.1 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (0.1.2)
# Requirement already satisfied: wcwidth in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.2.13)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from sympy>=1.13.3->torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (3.0.2)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium<5,>=4->finrl==0.3.8) (0.14.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from stack_data->ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from stack_data->ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (3.0.0)
# Requirement already satisfied: pure_eval in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from stack_data->ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.2.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (4.9.1)
# Requirement already satisfied: zipp>=3.20 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api==1.36.0->opentelemetry-sdk>=1.30.0->ray[default,tune]<3,>=2->finrl==0.3.8) (3.21.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\admin\anaconda3\envs\pyspark-env\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (0.6.1)
#   Running command git clone --filter=blob:none --quiet https://github.com/AI4Finance-Foundation/FinRL.git 'C:\Users\Admin\AppData\Local\Temp\pip-req-build-_ow2_5vt'
#   Running command git clone --filter=blob:none --quiet https://github.com/AI4Finance-Foundation/ElegantRL.git 'C:\Users\Admin\AppData\Local\Temp\pip-install-9z1w5efd\elegantrl_3ad6fb0bfbb94d7a81291d32c54c57a9'

# %%
# Import our Deep SARSA Agent
from deep_sarsa_agent import DeepSARSAAgent

# %%
import finrl
import pandas as pd
from finrl.agents.stablebaselines3.models import DRLAgent
from finrl.config import INDICATORS, TRAINED_MODEL_DIR, RESULTS_DIR
from finrl.main import check_and_make_directories
from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv

# %%
train = pd.read_csv(r'SARSA_FinancialRL\data\train_data.csv')
# Don't set the first column as index - FinRL needs integer index
# Just drop the unnamed index column if it exists
if 'Unnamed: 0' in train.columns:
    train = train.drop(columns=['Unnamed: 0'])

# Reset index to ensure it's a proper integer RangeIndex
train = train.reset_index(drop=True)

print(f"Loaded {len(train)} rows of training data")
print(f"Columns: {train.columns.tolist()}")
print(f"Index type: {type(train.index)}")
train.head()
# Out:
# Loaded 2556 rows of training data
# Columns: ['date', 'open', 'high', 'low', 'close', 'volume', 'tic', 'day', 'macd', 'rsi', 'cci', 'dx', 'atr']
# Index type: <class 'pandas.core.indexes.range.RangeIndex'>
#          date   open   high    low  close  volume  tic  day      macd  \
# 0  2015-01-13  29.16  29.74  29.01  29.74   84550  vnm    1  0.013013
# 1  2015-01-14  30.03  30.03  29.16  29.45   87550  vnm    2  0.007588
# 2  2015-01-15  29.45  29.45  29.01  29.16   86090  vnm    3 -0.005536
# 3  2015-01-16  29.16  29.16  29.01  29.16   33740  vnm    4 -0.012550
# 4  2015-01-19  29.16  29.16  28.87  29.01   60950  vnm    0 -0.022945
#
#           rsi         cci          dx       atr
# 0  100.000000   66.666667  100.000000  0.797407
# 1   65.000000  100.000000   38.095238  0.823419
# 2   47.206704 -133.333333    2.204929  0.716661
# 3   47.206704 -103.109656    2.204929  0.585941
# 4   40.548192  -99.904489   28.230517  0.527051

# %%
stock_dimension = len(train.tic.unique())
# Use the actual tech_indicator_list we're using, not FinRL's INDICATORS
tech_indicator_list = ["macd", "rsi", "cci", "dx", "atr"]
state_space = 1 + 2*stock_dimension + len(tech_indicator_list)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 1, State Space: 8

# %%
buy_cost_list = sell_cost_list = [0.001] * stock_dimension
num_stock_shares = [0] * stock_dimension

env_kwargs = {
    "hmax": 100,
    "initial_amount": 1000000,
    "num_stock_shares": num_stock_shares,
    "buy_cost_pct": buy_cost_list,
    "sell_cost_pct": sell_cost_list,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": tech_indicator_list,
    "action_space": stock_dimension,
    "reward_scaling": 1e-3  # TĂNG từ 1e-4 lên 1e-3 để reward có ý nghĩa hơn
}

print("Environment configuration:")
print(f"  Initial amount: {env_kwargs['initial_amount']:,}")
print(f"  Max shares per trade: {env_kwargs['hmax']}")
print(f"  Reward scaling: {env_kwargs['reward_scaling']}")

e_train_gym = StockTradingEnv(df = train, **env_kwargs)
print("\n✓ Environment created successfully!")

# %% [markdown]
# ## ⚠️ Critical Fix: Loss Instability
#
# ### Vấn đề phát hiện:
# Loss tăng liên tục từ 9.5M → 16.6M cho thấy **training không ổn định**
#
# ### Root Causes:
# 1. **Reward scaling quá nhỏ (1e-4)** → Rewards gần như = 0 → TD targets không có signal
# 2. **LR_UPDATE quá cao (0.8)** → TD update quá mạnh → destabilize learning
# 3. **Network learning rate quá cao (5e-4)** → Overshooting optimal values
# 4. **Không có gradient clipping** → Exploding gradients
#
# ### Solutions Applied:
#
# **1. Tăng Reward Scaling: 1e-4 → 1e-3 (×10)**
#    - Rewards có magnitude lớn hơn → meaningful signal cho learning
#
# **2. Giảm LR_UPDATE: 0.8 → 0.3 (÷2.7)**
#    - TD update nhẹ nhàng hơn: `target = 0.7 * old_Q + 0.3 * TD_target`
#    - Giảm variance trong training
#
# **3. Giảm Network Learning Rate: 5e-4 → 1e-4 (÷5)**
#    - Slow and steady learning
#    - Tránh overshooting
#
# **4. Tăng Network Capacity: [128,64] → [256,128]**
#    - Với 8-dimensional state, network lớn hơn capture patterns tốt hơn
#
# **5. Giảm Gamma: 0.95 → 0.90**
#    - Giảm variance từ long-term rewards
#    - Focus vào immediate profits
#
# **6. Giảm Batch Size & Epochs: 64×8 → 32×5**
#    - Training steps nhỏ hơn → ổn định hơn
#    - Tránh overfitting trên single trajectory
#
# **7. Thêm Gradient Clipping (trong code)**
#    - Clip gradient norm ≤ 1.0
#    - Ngăn exploding gradients
#
# ### Expected Results:
# ✅ Loss giảm hoặc ít nhất ổn định (không tăng)
# ✅ Sharpe ratio dương và cải thiện dần
# ✅ Rewards tăng qua các episodes

# %%
# Network hyperparameters
HIDDEN_SIZES = [256, 128]       # TĂNG network capacity
LEARNING_RATE = 1e-4            # GIẢM learning rate để ổn định
GAMMA = 0.90                    # GIẢM gamma để giảm variance
ACTION_DIM = 10  

# Create agent
agent = DeepSARSAAgent(
    env=e_train_gym,
    action_dim=ACTION_DIM,
    hidden_sizes=HIDDEN_SIZES,
    learning_rate=LEARNING_RATE,
    gamma=GAMMA
)

print("\n✓ Agent created successfully!")
print(f"   Learning Rate: {LEARNING_RATE}")
print(f"   Gamma: {GAMMA}")
print(f"   Network: {HIDDEN_SIZES}")
# Out:
# DeepSARSAAgent initialized:
#   State dimension: 8
#   Discrete action dimension: 10
#   Continuous action dimension: 1
#   Device: cpu
#   Network architecture: 8 -> [128, 64] -> 10
#
# ✓ Agent created successfully!

# %%
# Training hyperparameters
NUM_EPISODES = 80               # GIẢM xuống để test nhanh
EPSILON_START = 1.0             # BẮT ĐẦU với 100% exploration
EPSILON_END = 0.1               # TĂNG minimum exploration
EPSILON_DECAY = 0.96            # GIẢM chậm
LR_UPDATE = 0.3                 # GIẢM MẠNH TD learning rate để ổn định hơn
BATCH_SIZE = 32                 # GIẢM batch size để học ổn định hơn
EPOCHS_PER_TRAJECTORY = 5       # GIẢM epochs để tránh overfitting

print("="*60)
print("Starting Stabilized Training")
print("="*60)
print(f"Configuration:")
print(f"  Episodes: {NUM_EPISODES}")
print(f"  Epsilon: {EPSILON_START} -> {EPSILON_END} (decay={EPSILON_DECAY})")
print(f"  Batch size: {BATCH_SIZE}")
print(f"  Epochs per trajectory: {EPOCHS_PER_TRAJECTORY}")
print(f"  TD update lr: {LR_UPDATE} CRITICAL: Giảm để ổn định loss")
print("="*60)
print()

# Train
training_history = agent.train(
    num_episodes=NUM_EPISODES,
    epsilon_start=EPSILON_START,
    epsilon_end=EPSILON_END,
    epsilon_decay=EPSILON_DECAY,
    lr_update=LR_UPDATE,
    batch_size=BATCH_SIZE,
    epochs_per_trajectory=EPOCHS_PER_TRAJECTORY,
    verbose=True
)

print("\n" + "="*60)
print("✓ Training Complete!")
print("="*60)
# Out:
# ============================================================
# Starting Stabilized Training
# ============================================================
# Configuration:
#   Episodes: 80
#   Epsilon: 1.0 -> 0.1 (decay=0.96)
#   Batch size: 32
#   Epochs per trajectory: 5
#   TD update lr: 0.3 CRITICAL: Giảm để ổn định loss
# ============================================================
# Training Deep SARSA:   0%|          | 0/80 [00:00<?, ?it/s]
# Training Deep SARSA:   8%|▊         | 6/80 [00:35<07:27,  6.04s/it, reward=0.15, loss=6440266.8006, eps=0.783, steps=2556]
# day: 2555, episode: 340
# begin_total_asset: 1000000.00
# end_total_asset: 1001974.98
# total_reward: 1974.98
# total_cost: 1007.52
# total_trades: 1532
# Sharpe: 0.298
# =================================
# Training Deep SARSA:  20%|██        | 16/80 [01:40<06:54,  6.48s/it, reward=-0.03, loss=6667325.4725, eps=0.520, steps=2556]
# day: 2555, episode: 350
# begin_total_asset: 1000000.00
# end_total_asset: 1000322.98
# total_reward: 322.98
# total_cost: 1068.62
# total_trades: 1635
# Sharpe: 0.030
# =================================
# Training Deep SARSA:  32%|███▎      | 26/80 [02:49<06:24,  7.12s/it, reward=-0.07, loss=6902791.1069, eps=0.346, steps=2556]
# day: 2555, episode: 360
# begin_total_asset: 1000000.00
# end_total_asset: 999698.86
# total_reward: -301.14
# total_cost: 1060.54
# total_trades: 1630
# Sharpe: -0.058
# =================================
# Training Deep SARSA:  45%|████▌     | 36/80 [03:56<05:11,  7.08s/it, reward=0.69, loss=7121674.2663, eps=0.230, steps=2556]
# day: 2555, episode: 370
# begin_total_asset: 1000000.00
# end_total_asset: 998692.83
# total_reward: -1307.17
# total_cost: 1078.47
# total_trades: 1664
# Sharpe: -0.134
# =================================
# Training Deep SARSA:  57%|█████▊    | 46/80 [05:05<04:08,  7.32s/it, reward=-0.04, loss=7166990.5163, eps=0.153, steps=2556]
# day: 2555, episode: 380
# begin_total_asset: 1000000.00
# end_total_asset: 999845.46
# total_reward: -154.54
# total_cost: 1030.34
# total_trades: 1587
# Sharpe: -0.021
# =================================
# Training Deep SARSA:  70%|███████   | 56/80 [06:14<02:55,  7.31s/it, reward=-0.02, loss=7318920.6500, eps=0.102, steps=2556]
# day: 2555, episode: 390
# begin_total_asset: 1000000.00
# end_total_asset: 1002506.27
# total_reward: 2506.27
# total_cost: 1042.53
# total_trades: 1604
# Sharpe: 0.327
# =================================
# Training Deep SARSA:  82%|████████▎ | 66/80 [07:24<01:40,  7.19s/it, reward=-0.05, loss=7534918.6087, eps=0.068, steps=2556]
# day: 2555, episode: 400
# begin_total_asset: 1000000.00
# end_total_asset: 999920.05
# total_reward: -79.95
# total_cost: 1033.25
# total_trades: 1596
# Sharpe: -0.012
# =================================
# Training Deep SARSA:  95%|█████████▌| 76/80 [08:39<00:29,  7.27s/it, reward=-0.06, loss=7729153.8706, eps=0.045, steps=2556]
# day: 2555, episode: 410
# begin_total_asset: 1000000.00
# end_total_asset: 998933.08
# total_reward: -1066.92
# total_cost: 999.32
# total_trades: 1537
# Sharpe: -0.233
# =================================
# Training Deep SARSA: 100%|██████████| 80/80 [09:07<00:00,  6.84s/it, reward=0.12, loss=7757001.7050, eps=0.038, steps=2556]
# Training history plot saved to training_history.pdf
#
# ============================================================
# ✓ Training Complete!
# ============================================================
# d:\SARSA_finRL\deep_sarsa_agent.py:460: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
# Save model
model_path = r'D:\SARSA_finRL\SARSA_FinancialRL\Agent'
agent.save_model(model_path)

print(f"\n✓ Model saved to: {model_path}")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[11], line 3
#       1 # Save model
#       2 model_path = 'Agent/deep_sarsa_trained.pth'
# ----> 3 agent.save_model(model_path)
#       5 print(f"\n✓ Model saved to: {model_path}")
#
# File d:\SARSA_finRL\deep_sarsa_agent.py:474, in DeepSARSAAgent.save_model(self, filepath)
#     464 """Save agent's Q-network and training state"""
#     465 checkpoint = {
#     466     'q_network_state_dict': self.q_network.state_dict(),
#     467     'optimizer_state_dict': self.optimizer.state_dict(),
#    (...)    472     'gamma': self.gamma
#     473 }
# --> 474 torch.save(checkpoint, filepath)
#     475 print(f"Model saved to {filepath}")
#
# File c:\Users\Admin\anaconda3\envs\pyspark-env\Lib\site-packages\torch\serialization.py:966, in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization, _disable_byteorder_record)
#     963     f = os.fspath(f)
#     965 if _use_new_zipfile_serialization:
# --> 966     with _open_zipfile_writer(f) as opened_zipfile:
#     967         _save(
#     968             obj,
#     969             opened_zipfile,
#    (...)    972             _disable_byteorder_record,
#     973         )
#     974         return
#
# File c:\Users\Admin\anaconda3\envs\pyspark-env\Lib\site-packages\torch\serialization.py:828, in _open_zipfile_writer(name_or_buffer)
#     826 else:
#     827     container = _open_zipfile_writer_buffer
# --> 828 return container(name_or_buffer)
#
# File c:\Users\Admin\anaconda3\envs\pyspark-env\Lib\site-packages\torch\serialization.py:792, in _open_zipfile_writer_file.__init__(self, name)
#     785     super().__init__(
#     786         torch._C.PyTorchFileWriter(
#     787             self.file_stream, get_crc32_options(), _get_storage_alignment()
#     788         )
#     789     )
#     790 else:
#     791     super().__init__(
# --> 792         torch._C.PyTorchFileWriter(
#     793             self.name, get_crc32_options(), _get_storage_alignment()
#     794         )
#     795     )
#
# RuntimeError: Parent directory Agent does not exist.

# %%
# Analyze training results
import matplotlib.pyplot as plt

print("\n📊 Training Summary:")
print("="*60)
if training_history:
    # Find best episode
    best_episode = max(training_history, key=lambda x: x['total_reward'])
    worst_episode = min(training_history, key=lambda x: x['total_reward'])
    
    print(f"Best Episode #{best_episode['episode']}:")
    print(f"  Total Reward: {best_episode['total_reward']:.2f}")
    print(f"  Sharpe Ratio: {best_episode['sharpe']:.3f}")
    print(f"  Total Trades: {best_episode['total_trades']}")
    print(f"  Final Asset: {best_episode['end_total_asset']:.2f}")
    print()
    print(f"Worst Episode #{worst_episode['episode']}:")
    print(f"  Total Reward: {worst_episode['total_reward']:.2f}")
    print(f"  Sharpe Ratio: {worst_episode['sharpe']:.3f}")
    print()
    
    # Calculate average metrics
    avg_reward = sum(ep['total_reward'] for ep in training_history) / len(training_history)
    avg_sharpe = sum(ep['sharpe'] for ep in training_history) / len(training_history)
    avg_trades = sum(ep['total_trades'] for ep in training_history) / len(training_history)
    
    print(f"Average Metrics:")
    print(f"  Avg Reward: {avg_reward:.2f}")
    print(f"  Avg Sharpe: {avg_sharpe:.3f}")
    print(f"  Avg Trades: {avg_trades:.0f}")
    
print("="*60)

# %%
# Plot loss trend to diagnose training
import matplotlib.pyplot as plt
import numpy as np

if training_history:
    episodes = [ep['episode'] for ep in training_history]
    rewards = [ep['total_reward'] for ep in training_history]
    sharpes = [ep['sharpe'] for ep in training_history]
    
    fig, axes = plt.subplots(1, 2, figsize=(14, 4))
    
    # Plot 1: Reward trend
    axes[0].plot(episodes, rewards, marker='o', markersize=3, linewidth=1.5, alpha=0.7)
    axes[0].axhline(y=0, color='r', linestyle='--', alpha=0.5, label='Break-even')
    axes[0].set_xlabel('Episode')
    axes[0].set_ylabel('Total Reward')
    axes[0].set_title('📈 Reward Progression')
    axes[0].grid(True, alpha=0.3)
    axes[0].legend()
    
    # Plot 2: Sharpe ratio trend
    axes[1].plot(episodes, sharpes, marker='s', markersize=3, linewidth=1.5, alpha=0.7, color='green')
    axes[1].axhline(y=0, color='r', linestyle='--', alpha=0.5, label='Zero Sharpe')
    axes[1].set_xlabel('Episode')
    axes[1].set_ylabel('Sharpe Ratio')
    axes[1].set_title('📊 Sharpe Ratio Progression')
    axes[1].grid(True, alpha=0.3)
    axes[1].legend()
    
    plt.tight_layout()
    plt.savefig('training_metrics.png', dpi=150, bbox_inches='tight')
    print("✓ Training metrics plot saved to training_metrics.png")
    plt.show()
    
    # Performance analysis
    print("\n" + "="*60)
    print("🎯 Performance Diagnosis:")
    print("="*60)
    
    positive_rewards = [r for r in rewards if r > 0]
    negative_rewards = [r for r in rewards if r < 0]
    
    print(f"Profitable episodes: {len(positive_rewards)}/{len(rewards)} ({len(positive_rewards)/len(rewards)*100:.1f}%)")
    print(f"Loss-making episodes: {len(negative_rewards)}/{len(rewards)} ({len(negative_rewards)/len(rewards)*100:.1f}%)")
    
    if positive_rewards:
        print(f"Avg profit when winning: {np.mean(positive_rewards):.2f}")
    if negative_rewards:
        print(f"Avg loss when losing: {np.mean(negative_rewards):.2f}")
    
    # Trend analysis
    first_half_reward = np.mean(rewards[:len(rewards)//2])
    second_half_reward = np.mean(rewards[len(rewards)//2:])
    improvement = second_half_reward - first_half_reward
    
    print(f"\nLearning Progress:")
    print(f"  First half avg reward: {first_half_reward:.2f}")
    print(f"  Second half avg reward: {second_half_reward:.2f}")
    print(f"  Improvement: {improvement:+.2f} ({'✅ LEARNING' if improvement > 0 else '⚠️ NOT IMPROVING'})")
    print("="*60)
